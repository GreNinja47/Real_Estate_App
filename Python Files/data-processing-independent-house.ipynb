# %%
## Read google drive file
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('/content/gdrive/MyDrive/Project - Real Estate/independent-house.csv')

# %%
df1=df.copy()

# %%
df.head()
# Out:
#                                       property_name  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon
# 1  5 Bedroom House for sale in Sector 21A Faridabad
# 2  10 Bedroom House for sale in Sushant Lok Phase 1
# 3    21 Bedroom House for sale in Sector 54 Gurgaon
# 4  12 Bedroom House for sale in Sushant Lok Phase 1
#
#                                                 link           society  \
# 0  https://www.99acres.com/5-bhk-bedroom-independ...  Bptp Visionnaire
# 1  https://www.99acres.com/5-bhk-bedroom-independ...               NaN
# 2  https://www.99acres.com/10-bhk-bedroom-indepen...               NaN
# 3  https://www.99acres.com/21-bhk-bedroom-indepen...               NaN
# 4  https://www.99acres.com/12-bhk-bedroom-indepen...               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# ...

# %%
df.shape
# Out:
# (1095, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    1095 non-null   object
#  1   link             1095 non-null   object
#  2   society          471 non-null    object
#  3   price            968 non-null    object
#  4   rate             1054 non-null   object
#  5   area             1095 non-null   object
#  6   areaWithType     987 non-null    object
#  7   bedRoom          987 non-null    object
#  8   bathroom         987 non-null    object
#  9   balcony          987 non-null    object
#  10  additionalRoom   589 non-null    object
#  11  address          1031 non-null   object
#  12  noOfFloor        967 non-null    object
#  13  facing           674 non-null    object
#  14  agePossession    987 non-null    object
#  15  nearbyLocations  913 non-null    object
# ...

# %%
# check for duplicates
df.duplicated().sum()
# Out:
# 13

# %%
df[df.duplicated()]
# Out:
#                                          property_name  \
# 820     4 Bedroom House for sale in Sector 70A Gurgaon
# 821  4 Bedroom House for sale in C Block Sushant Lo...
# 822            3 Bedroom House for sale in Palam Vihar
# 823            8 Bedroom House for sale in Palam Vihar
# 824         5 Bedroom House for sale in Greenwood City
# 825     4 Bedroom House for sale in Sector 112 Gurgaon
# 826        6 Bedroom House for sale in Uppals Southend
# 827      3 Bedroom House for sale in Sector 48 Gurgaon
# 828      4 Bedroom House for sale in Sector 48 Gurgaon
# 829      4 Bedroom House for sale in Sector 55 Gurgaon
# 830      4 Bedroom House for sale in Sector 91 Gurgaon
# 831      4 Bedroom House for sale in Sector 86 Gurgaon
# 871           12 Bedroom House for sale in DLF Phase 1
#
#                                                   link  \
# 820  https://www.99acres.com/4-bhk-bedroom-independ...
# 821  https://www.99acres.com/4-bhk-bedroom-independ...
# ...

# %%
df = df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# property_name        0
# link                 0
# society            619
# price              127
# rate                41
# area                 0
# areaWithType       108
# bedRoom            108
# bathroom           108
# balcony            108
# additionalRoom     504
# address             64
# noOfFloor          127
# facing             420
# agePossession      108
# nearbyLocations    182
# description         59
# furnishDetails     350
# features           420
# rating             188
# property_id         59
# dtype: int64

# %%
#society contains missing value
df[df['society'].isna()]
# Out:
#                                           property_name  \
# 1      5 Bedroom House for sale in Sector 21A Faridabad
# 2      10 Bedroom House for sale in Sushant Lok Phase 1
# 3        21 Bedroom House for sale in Sector 54 Gurgaon
# 4      12 Bedroom House for sale in Sushant Lok Phase 1
# 5      20 Bedroom House for sale in Sushant Lok Phase 1
# 8               6 Bedroom House for sale in DLF Phase 2
# 10              4 Bedroom House for sale in DLF Phase 2
# 11              6 Bedroom House for sale in DLF Phase 4
# 13              5 Bedroom House for sale in DLF Phase 1
# 14    5 Bedroom House for sale in B Block Sushant Lo...
# 15    6 Bedroom House for sale in New Palam Vihar Ph...
# 17        7 Bedroom House for sale in Sector 38 Gurgaon
# 19          6 Bedroom House for sale in Uppals Southend
# 20         9 Bedroom House for sale in Sector 9 Gurgaon
# 22        4 Bedroom House for sale in Sector 48 Gurgaon
# 24              9 Bedroom House for sale in DLF Phase 2
# ...

# %%
# Observation : There are 619 missing data on society so it will be replaced as independent
# df['society'] = df['society'].str.replace('nan', 'independent')

df['society'].fillna('independent', inplace=True)

# %%
df['society'].value_counts()
# Out:
# independent                                          619
# Emaar MGF Marbella                                    26
# International City by SOBHA Phase 2                   26
# Vipul Tatvam Villa                                    25
# International City by Sobha Phase 1                   23
# Unitech Uniworld Resorts                              14
# DLF City Plots                                        11
# DLF City Plots Phase 2                                11
# Unitech Espace                                        11
# Eldeco Mansionz                                        9
# Bptp Visionnaire                                       8
# Uppal Southend4.0 ★                                    8
# Not Applicable                                         7
# Ansals Palam Vihar                                     6
# Sushant Lok 1 Builder Floors                           6
# Experion Windchants3.8 ★                               5
# ...

# %%
import re
df['society'] = df['society'].apply(lambda name: re.sub(r'\d+(\.\d+)?\s?★', '', str(name)).strip()).str.lower()

# %%
df['society'].value_counts()
# Out:
# independent                                          619
# emaar mgf marbella                                    26
# international city by sobha phase 2                   26
# vipul tatvam villa                                    25
# international city by sobha phase 1                   23
# unitech uniworld resorts                              14
# dlf city plots phase 2                                11
# unitech espace                                        11
# dlf city plots                                        11
# eldeco mansionz                                        9
# bptp visionnaire                                       8
# uppal southend                                         8
# not applicable                                         7
# sushant lok 1 builder floors                           6
# ansals palam vihar                                     6
# experion windchants                                    5
# ...

# %%
df['society'].value_counts().shape
# Out:
# (186,)

# %%
df[df['society'] == 'nul']
# Out:
#                                  property_name  \
# 46     5 Bedroom House for sale in DLF Phase 2
# 794    5 Bedroom House for sale in DLF Phase 2
# 1057   9 Bedroom House for sale in DLF Phase 2
# 1061  16 Bedroom House for sale in DLF Phase 4
#
#                                                    link society       price  \
# 46    https://www.99acres.com/5-bhk-bedroom-independ...     nul  6.25 Crore
# 794   https://www.99acres.com/5-bhk-bedroom-independ...     nul    15 Crore
# 1057  https://www.99acres.com/9-bhk-bedroom-independ...     nul   9.5 Crore
# 1061  https://www.99acres.com/16-bhk-bedroom-indepen...     nul  12.5 Crore
#
#                  rate                       area  \
# 46    ₹ 34,722/sq.ft.      (167 sq.m.) Plot Area
# 794   ₹ 23,437/sq.ft.  (595 sq.m.) Built-up Area
# 1057  ₹ 33,404/sq.ft.      (264 sq.m.) Plot Area
# 1061  ₹ 51,440/sq.ft.      (226 sq.m.) Plot Area
#
#                             areaWithType      bedRoom      bathroom  \
# ...

# %%
# Observation, as the houses data are largely the independent housing sectors so appending the nul missing values as independent
df.loc[46, 'society'] = 'independent'
df.loc[794, 'society'] = 'independent'
df.loc[1057, 'society'] = 'independent'
df.loc[1061, 'society'] = 'independent'

# %%
df[df['society'] == 'nul']
# Out:
# Empty DataFrame
# Columns: [property_name, link, society, price, rate, area, areaWithType, bedRoom, bathroom, balcony, additionalRoom, address, noOfFloor, facing, agePossession, nearbyLocations, description, furnishDetails, features, rating, property_id]
# Index: []

# %%
# bedrooms
df['bedRoom'].value_counts()
# Out:
# 4 Bedrooms     233
# 5 Bedrooms     196
# 3 Bedrooms     149
# 2 Bedrooms      91
# 6 Bedrooms      81
# 9 Bedrooms      45
# 1 Bedroom       38
# 8 Bedrooms      33
# 7 Bedrooms      32
# 12 Bedrooms     28
# 10 Bedrooms     21
# 16 Bedrooms     12
# 13 Bedrooms      4
# 18 Bedrooms      2
# 19 Bedrooms      2
# 11 Bedrooms      2
# 20 Bedrooms      1
# 21 Bedrooms      1
# 36 Bedrooms      1
# 34 Bedrooms      1
# 14 Bedrooms      1
# Name: bedRoom, dtype: int64

# %%
# most of missing value rows of other columns too are missing
df[df['bedRoom'].isnull()]
# Out:
#                                           property_name  \
# 60        4 Bedroom House for sale in Sector 86 Gurgaon
# 61    8 Bedroom House for sale in B1 Block Sector 57...
# 62              6 Bedroom House for sale in DLF Phase 1
# 63      6 Bedroom House for sale in Sushant Lok Phase 3
# 64      6 Bedroom House for sale in Sushant Lok Phase 3
# 65              4 Bedroom House for sale in DLF Phase 4
# 66          8 Bedroom House for sale in Uppals Southend
# 67          6 Bedroom House for sale in Uppals Southend
# 68        4 Bedroom House for sale in Sector 48 Gurgaon
# 69              4 Bedroom House for sale in Malibu Town
# 70        5 Bedroom House for sale in Sector 33 Gurgaon
# 71              5 Bedroom House for sale in DLF Phase 1
# 72             3 Bedroom House for sale in South City 1
# 75       5 Bedroom House for sale in Sector 109 Gurgaon
# 76       4 Bedroom House for sale in Sector 109 Gurgaon
# 79        5 Bedroom House for sale in Sector 66 Gurgaon
# ...

# %%
df = df[~df['bedRoom'].isnull()]

# %%
df.shape
# Out:
# (974, 21)

# %%
df['bedRoom'] = df['bedRoom'].str.split(' ').str.get(0).astype('int')

# %%
df.head(2)
# Out:
#                                       property_name  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon
# 1  5 Bedroom House for sale in Sector 21A Faridabad
#
#                                                 link           society  \
# 0  https://www.99acres.com/5-bhk-bedroom-independ...  bptp visionnaire
# 1  https://www.99acres.com/5-bhk-bedroom-independ...       independent
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
#
#                   areaWithType  bedRoom     bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)        5  4 Bathrooms  3+ Balconies
# 1   Plot area 539(50.07 sq.m.)        5  4 Bathrooms   2 Balconies
#
#                        additionalRoom  \
# 0                        Servant Room
# 1  Store Room,Pooja Room,Servant Room
#
#                                      address noOfFloor      facing  \
# ...

# %%
# bathroom
df['bathroom'].value_counts()
# Out:
# 4 Bathrooms     229
# 3 Bathrooms     166
# 5 Bathrooms     137
# 2 Bathrooms     118
# 6 Bathrooms      83
# 1 Bathroom       67
# 9 Bathrooms      42
# 7 Bathrooms      39
# 8 Bathrooms      29
# 12 Bathrooms     22
# 10 Bathrooms     11
# 16 Bathrooms      8
# 18 Bathrooms      4
# 13 Bathrooms      4
# 11 Bathrooms      4
# 20 Bathrooms      3
# 17 Bathrooms      3
# 14 Bathrooms      2
# 21 Bathrooms      1
# 36 Bathrooms      1
# 34 Bathrooms      1
# Name: bathroom, dtype: int64

# %%
df[df['bedRoom'].isnull()]
# Out:
# Empty DataFrame
# Columns: [property_name, link, society, price, rate, area, areaWithType, bedRoom, bathroom, balcony, additionalRoom, address, noOfFloor, facing, agePossession, nearbyLocations, description, furnishDetails, features, rating, property_id]
# Index: []

# %%
df['bathroom'] = df['bathroom'].str.split(' ').str.get(0).astype('int')

# %%
df.head()
# Out:
#                                       property_name  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon
# 1  5 Bedroom House for sale in Sector 21A Faridabad
# 2  10 Bedroom House for sale in Sushant Lok Phase 1
# 3    21 Bedroom House for sale in Sector 54 Gurgaon
# 4  12 Bedroom House for sale in Sushant Lok Phase 1
#
#                                                 link           society  \
# 0  https://www.99acres.com/5-bhk-bedroom-independ...  bptp visionnaire
# 1  https://www.99acres.com/5-bhk-bedroom-independ...       independent
# 2  https://www.99acres.com/10-bhk-bedroom-indepen...       independent
# 3  https://www.99acres.com/21-bhk-bedroom-indepen...       independent
# 4  https://www.99acres.com/12-bhk-bedroom-indepen...       independent
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# ...

# %%
# balcony
df['balcony'].value_counts()
# Out:
# 3+ Balconies    366
# 2 Balconies     221
# 3 Balconies     161
# No Balcony      118
# 1 Balcony       108
# Name: balcony, dtype: int64

# %%
df['balcony'] = df['balcony'].str.split(' ').str.get(0).str.replace('No','0')

# %%
df['balcony'].isnull().sum()
# Out:
# 0

# %%
df['balcony'].value_counts()
# Out:
# 3+    366
# 2     221
# 3     161
# 0     118
# 1     108
# Name: balcony, dtype: int64

# %%
df.isna().sum()
# Out:
# property_name        0
# link                 0
# society              0
# price               19
# rate                29
# area                 0
# areaWithType         0
# bedRoom              0
# bathroom             0
# balcony              0
# additionalRoom     396
# address              5
# noOfFloor           19
# facing             312
# agePossession        0
# nearbyLocations    123
# description          0
# furnishDetails     242
# features           312
# rating             122
# property_id          0
# dtype: int64

# %%
# price
df['price'].value_counts()
# Out:
# 3.5 Crore           19
# 5.5 Crore           17
# 6.5 Crore           16
# 6 Crore             14
# 5 Crore             13
# 4.5 Crore           13
# 70 Lac              13
# 8 Crore             13
# 50 Lac              13
# 75 Lac              13
# 8.5 Crore           12
# 7 Crore             12
# 85 Lac              12
# 1.5 Crore           11
# 4 Crore             11
# 10 Crore            10
# Price on Request    10
# 45 Lac              10
# 2.25 Crore          10
# 2.5 Crore           10
# 60 Lac              10
# 90 Lac              10
# 9 Crore             10
# 9.5 Crore            9
# 12 Crore             9
# 80 Lac               9
# 1.7 Crore            9
# 2 Crore              9
# 1.1 Crore            9
# 1 Crore              8
# 6.75 Crore           8
# 11 Crore             8
# 1.6 Crore            8
# 4.6 Crore            8
# 1.3 Crore            7
# 95 Lac               7
# 12.5 Crore           7
# 3.75 Crore           7
# 1.2 Crore            7
# 55 Lac               7
# ...

# %%
# insights : removing the 10 rows with value count as Price on Request
df = df[df['price'] != 'Price on Request']

# %%
df[df['price'].isnull()]
# Out:
#                                         property_name  \
# 47      5 Bedroom House for sale in Sector 66 Gurgaon
# 285     6 Bedroom House for sale in Sector 11 Gurgaon
# 334          2 Bedroom House for sale in Shakti Nagar
# 418    5 Bedroom House for sale in Sector 108 Gurgaon
# 483          5 Bedroom House for sale in Laxman Vihar
# 491   4 Bedroom House for sale in Udyog Vihar Phase 1
# 509         7 Bedroom House for sale in Naharpur Rupa
# 631           5 Bedroom House for sale in DLF Phase 3
# 778          12 Bedroom House for sale in DLF Phase 2
# 786     5 Bedroom House for sale in Sector 33 Gurgaon
# 815     5 Bedroom House for sale in Sector 66 Gurgaon
# 842     5 Bedroom House for sale in Sector 33 Gurgaon
# 850          16 Bedroom House for sale in DLF Phase 4
# 867       5 Bedroom House for sale in Nirvana Country
# 891     9 Bedroom House for sale in Sector 45 Gurgaon
# 967           5 Bedroom House for sale in DLF Phase 2
# ...

# %%
# Removing the missing value rows
df=df[~df['price'].isnull()]

# %%
def price(x):
    if type(x) == float:
        return x
    else:
        if x[1] == 'Lac':
            return round(float(x[0])/100,2)
        else:
            return round(float(x[0]),2)

# %%
df['price'] = df['price'].str.split(' ').apply(price)

# %%
df.isna().sum()
# Out:
# property_name        0
# link                 0
# society              0
# price                0
# rate                 0
# area                 0
# areaWithType         0
# bedRoom              0
# bathroom             0
# balcony              0
# additionalRoom     379
# address              5
# noOfFloor           19
# facing             297
# agePossession        0
# nearbyLocations    115
# description          0
# furnishDetails     230
# features           298
# rating             120
# property_id          0
# dtype: int64

# %%
# rename column
df.rename(columns={'rate':'price_per_sqft'},inplace=True)

# %%
df['price_per_sqft'] = df['price_per_sqft'].str.split('/').str.get(0).str.replace('₹','').str.replace(',','').str.strip().astype('float')

# %%
df.head()
# Out:
#                                       property_name  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon
# 1  5 Bedroom House for sale in Sector 21A Faridabad
# 2  10 Bedroom House for sale in Sushant Lok Phase 1
# 3    21 Bedroom House for sale in Sector 54 Gurgaon
# 4  12 Bedroom House for sale in Sushant Lok Phase 1
#
#                                                 link           society  price  \
# 0  https://www.99acres.com/5-bhk-bedroom-independ...  bptp visionnaire   5.25
# 1  https://www.99acres.com/5-bhk-bedroom-independ...       independent   5.70
# 2  https://www.99acres.com/10-bhk-bedroom-indepen...       independent   2.10
# 3  https://www.99acres.com/21-bhk-bedroom-indepen...       independent   5.00
# 4  https://www.99acres.com/12-bhk-bedroom-indepen...       independent   3.00
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# ...

# %%
df['price_per_sqft'].value_counts()
# Out:
# 22222.0     13
# 11111.0     11
# 33333.0     11
# 10000.0     10
# 31481.0      6
# 37037.0      6
# 26235.0      6
# 30556.0      6
# 26667.0      6
# 9444.0       5
# 23333.0      5
# 5000.0       5
# 23148.0      5
# 8000.0       5
# 8889.0       5
# 18889.0      4
# 24691.0      4
# 34722.0      4
# 21605.0      4
# 35000.0      4
# 32407.0      4
# 9722.0       4
# 27778.0      4
# 13333.0      4
# 36111.0      3
# 10556.0      3
# 14815.0      3
# 11250.0      3
# 20000.0      3
# 6944.0       3
# 33951.0      3
# 12222.0      3
# 60000.0      3
# 13889.0      3
# 8235.0       3
# 5555.0       3
# 8444.0       3
# 8333.0       3
# 25000.0      3
# 29880.0      3
# 12000.0      3
# 15625.0      3
# 50000.0      3
# 32222.0      3
# 15555.0      3
# 25926.0      3
# 100000.0     2
# 21124.0      2
# 59259.0      2
# 44444.0      2
# 9000.0       2
# 38580.0      2
# 17778.0      2
# 6666.0       2
# 75000.0      2
# 24306.0      2
# 24845.0      2
# 10753.0      2
# ...

# %%
# additionalRoom
df['additionalRoom'].value_counts()
# Out:
# Servant Room                                     80
# Pooja Room,Study Room,Servant Room,Store Room    59
# Others                                           58
# Pooja Room                                       38
# Pooja Room,Study Room,Servant Room               32
# Store Room                                       31
# Pooja Room,Study Room,Servant Room,Others        29
# Pooja Room,Servant Room                          24
# Study Room                                       18
# Study Room,Servant Room                          18
# Servant Room,Store Room                          12
# Pooja Room,Study Room                            11
# Pooja Room,Store Room                            11
# Pooja Room,Others                                11
# Servant Room,Pooja Room                           8
# Servant Room,Others                               8
# Pooja Room,Servant Room,Store Room                7
# Pooja Room,Store Room,Study Room,Servant Room     7
# ...

# %%
df['additionalRoom'].fillna('not available',inplace=True)

# %%
df['additionalRoom'] = df['additionalRoom'].str.lower()

# %%
# floors
df['noOfFloor'].value_counts()
# Out:
# 3 Floors     299
# 2 Floors     282
# 1 Floors     179
# 4 Floors     130
# 5 Floors       9
# 0 Floors       6
# 14 Floors      3
# 6 Floors       3
# 11 Floors      2
# 12 Floors      2
# 10 Floors      2
# 16 Floors      1
# 51 Floors      1
# 41 Floors      1
# 27 Floors      1
# 20 Floors      1
# 13 Floors      1
# 21 Floors      1
# 02 Floors      1
# 33 Floors      1
# Name: noOfFloor, dtype: int64

# %%
df['noOfFloor'].isnull().sum()
# Out:
# 19

# %%
df = df[~df['noOfFloor'].isnull()]

# %%
df['noOfFloor'] = df['noOfFloor'].str.split(' ').str.get(0)
# Out:
# <ipython-input-601-10cbc4b5b6c6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['noOfFloor'] = df['noOfFloor'].str.split(' ').str.get(0)

# %%
df.rename(columns={'noOfFloor':'floorNum'},inplace=True)
# Out:
# <ipython-input-602-0e9522cda22b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'noOfFloor':'floorNum'},inplace=True)

# %%
df.head()
# Out:
#                                       property_name  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon
# 1  5 Bedroom House for sale in Sector 21A Faridabad
# 2  10 Bedroom House for sale in Sushant Lok Phase 1
# 3    21 Bedroom House for sale in Sector 54 Gurgaon
# 4  12 Bedroom House for sale in Sushant Lok Phase 1
#
#                                                 link           society  price  \
# 0  https://www.99acres.com/5-bhk-bedroom-independ...  bptp visionnaire   5.25
# 1  https://www.99acres.com/5-bhk-bedroom-independ...       independent   5.70
# 2  https://www.99acres.com/10-bhk-bedroom-indepen...       independent   2.10
# 3  https://www.99acres.com/21-bhk-bedroom-indepen...       independent   5.00
# 4  https://www.99acres.com/12-bhk-bedroom-indepen...       independent   3.00
#
#    price_per_sqft                   area                 areaWithType  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# ...

# %%
# facing
df['facing'].value_counts()
# Out:
# East          174
# North-East    155
# North         107
# West           70
# North-West     43
# South-East     37
# South          33
# South-West     22
# Name: facing, dtype: int64

# %%
df['facing'].isnull().sum()
# Out:
# 285

# %%
df['facing'].fillna('NA',inplace=True)
# Out:
# <ipython-input-606-e6ba103970bd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['facing'].fillna('NA',inplace=True)

# %%
# agePossession
df['agePossession'].isna().sum()
# Out:
# 0

# %%
df['agePossession'].value_counts()
# Out:
# 5 to 10 Year Old      238
# 1 to 5 Year Old       217
# 10+ Year Old          206
# undefined             141
# 0 to 1 Year Old       105
# Within 6 months         7
# Jun 2024                2
# Dec 2023                2
# Under Construction      2
# Oct 2024                1
# By 2024                 1
# Dec 2024                1
# Within 3 months         1
# Oct 2023                1
# Jan 2024                1
# Name: agePossession, dtype: int64

# %%
def categorize_age_possession(value):
    if pd.isna(value):
        return "Undefined"

    if "0 to 1 Year Old" in value or "Within 6 months" in value or "Within 3 months" in value:
        return "New Property"

    if "1 to 5 Year Old" in value:
        return "Relatively New"

    if "5 to 10 Year Old" in value:
        return "Moderately Old"

    if "10+ Year Old" in value:
        return "Old Property"

    if "Under Construction" in value or "By" in value:
        return "Under Construction"

    try:
        # For entries like 'May 2024'
        if value.split(" ")[-1].isdigit():
            return "Under Construction"
    except:
        pass  # If an error occurs, do nothing and proceed to the next step

    return "Undefined"  # If none of the conditions are met, return "Undefined"

# %%
df['agePossession'] = df['agePossession'].apply(categorize_age_possession)

# %%
df['agePossession'].value_counts()
# Out:
# Moderately Old        238
# Relatively New        217
# Old Property          206
# Undefined             141
# New Property          113
# Under Construction     11
# Name: agePossession, dtype: int64

# %%
df.insert(loc=1,column='property_type',value='house')

# %%
df['area'] = round((df['price']*10000000)/df['price_per_sqft'])

# %%
df.head()
# Out:
#                                       property_name property_type  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon         house
# 1  5 Bedroom House for sale in Sector 21A Faridabad         house
# 2  10 Bedroom House for sale in Sushant Lok Phase 1         house
# 3    21 Bedroom House for sale in Sector 54 Gurgaon         house
# 4  12 Bedroom House for sale in Sushant Lok Phase 1         house
#
#                                                 link           society  price  \
# 0  https://www.99acres.com/5-bhk-bedroom-independ...  bptp visionnaire   5.25
# 1  https://www.99acres.com/5-bhk-bedroom-independ...       independent   5.70
# 2  https://www.99acres.com/10-bhk-bedroom-indepen...       independent   2.10
# 3  https://www.99acres.com/21-bhk-bedroom-indepen...       independent   5.00
# 4  https://www.99acres.com/12-bhk-bedroom-indepen...       independent   3.00
#
#    price_per_sqft    area                 areaWithType  bedRoom  bathroom  \
# ...

# %%
df.isna().sum()
# the remaining missing values are string types which will be analysis post merging the datasets
# Out:
# property_name        0
# property_type        0
# link                 0
# society              0
# price                0
# price_per_sqft       0
# area                 0
# areaWithType         0
# bedRoom              0
# bathroom             0
# balcony              0
# additionalRoom       0
# address              5
# floorNum             0
# facing               0
# agePossession        0
# nearbyLocations    114
# description          0
# furnishDetails     227
# features           290
# rating             116
# property_id          0
# dtype: int64

# %%
# df.to_csv('cleaned_data-processing-flat.csv')
df.to_csv('/content/gdrive/MyDrive/Project - Real Estate/cleaned_data-processing-independent-house.csv',index=False)
